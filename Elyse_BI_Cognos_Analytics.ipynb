# %% [markdown]
# <a href="https://colab.research.google.com/github/Epvargas/Elyse-BI-Dashboards/blob/main/Elyse_BI_Cognos_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Wheather Dashboard - Cognos Analytics

# %% [markdown]
# ![2021-04-19 (15).png](data:image/png;base64,...)

# %% [markdown]
# ![2021-04-19 (13).png](data:image/png;base64,...)

# %% [markdown]
# ![2021-04-19 (14).png](data:image/png;base64,...)

# %% [markdown]
# #  Retail Operations Dashboard - Cognos Analytics

# %% [markdown]
# ![2021-04-19 (11).png](data:image/png;base64,...)

# %% [markdown]
# ![2021-04-19 (8).png](data:image/png;base64,...)

# %% [markdown]
# #  Variables correlations - Cognos Analytics

# %% [markdown]
# ![2021-04-11 (12).png](data:image/png;base64,...)
